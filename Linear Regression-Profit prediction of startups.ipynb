# %% [markdown]
# # MULTILINEAR REGRESSION

# %%
##importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
##Reading data set
dataset=pd.read_csv('50_Startups.csv')

# %%
##Top 5 values of dataset
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
##R&D Spend vs Profit
dataset.plot(x='R&D Spend', y='Profit',style='o' )    
plt.title('R&D Spend vs Profit')    
plt.xlabel('R&D Spend')    
plt.ylabel('Profit')    
plt.show()

# %%
##Administration vs Profit
dataset.plot(x='Administration', y='Profit',style='o' )    
plt.title('Administration vs Profit')    
plt.xlabel('Administration')    
plt.ylabel('Profit')    
plt.show()

# %%
##Marketing Spend vs Profit
dataset.plot(x='Marketing Spend', y='Profit',style='o' )    
plt.title('Marketing Spend vs Profit')    
plt.xlabel('Marketing Spend')    
plt.ylabel('Profit')    
plt.show()

# %%
x=dataset.iloc[:,:-1] ##independent
y=dataset.iloc[:,4] ##dependent

# %% [markdown]
# ## Data Pre-processing

# %%
## Converting categorical features into numeric 
states=pd.get_dummies(x['State'],drop_first=True)

# %%
## Dropping state colm
x=x.drop('State',axis=1)

# %%
##concatinating the dummy with the real x
x=pd.concat([x,states],axis=1)

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  Florida  New York
# 0  165349.20       136897.80        471784.10        0         1
# 1  162597.70       151377.59        443898.53        0         0
# 2  153441.51       101145.55        407934.54        1         0
# 3  144372.41       118671.85        383199.62        0         1
# 4  142107.34        91391.77        366168.42        1         0

# %% [markdown]
# # Splitting training and testing dataset

# %%
from sklearn.model_selection import train_test_split  
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
##fitting multiple linear regression to training set
from sklearn.linear_model import LinearRegression 
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

# %%
y_train.head()
# Out:
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# Name: Profit, dtype: float64

# %%
y_pred
# Out:
# array([103015.20159796, 132582.27760816, 132447.73845174,  71976.09851258,
#        178537.48221055, 116161.24230165,  67851.69209676,  98791.73374687,
#        113969.43533012, 167921.0656955 ])

# %%
y_train
# Out:
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# 7     155752.60
# 14    132602.65
# 45     64926.08
# 48     35673.41
# 29    101004.64
# 15    129917.04
# 30     99937.59
# 32     97427.84
# 16    126992.93
# 42     71498.49
# 20    118474.03
# 43     69758.98
# 8     152211.77
# 13    134307.35
# 25    107404.34
# 5     156991.12
# 17    125370.37
# 40     78239.91
# 49     14681.40
# 1     191792.06
# 12    141585.52
# 37     89949.14
# 24    108552.04
# 6     156122.51
# 23    108733.99
# 36     90708.19
# 21    111313.02
# 19    122776.86
# 9     149759.96
# 39     81005.76
# 46     49490.75
# 3     182901.99
# 0     192261.83
# 47     42559.73
# 44     65200.33
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# Name: Profit, dtype: float64

# %%
score
# Out:
# 0.9347068473282423

# %% [markdown]
# ## summary

# %%
##step1-extracting the data_set
##step2-seprating dependent and independent colms.
##step3-convert catogarial feture into numbers
##step3-remove the categorial colm
##step4-concatinate the dummy features
##step5-split the data into test and train set
##step5-import linear regression from sklearn
